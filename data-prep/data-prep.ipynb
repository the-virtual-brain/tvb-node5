# %%
# !jupyter nbconvert data-prep.ipynb --to slides --ServePostProcessor.ip=0.0.0.0 --post serve
# Out:
# [NbConvertApp] Converting notebook data-prep.ipynb to slides
# [NbConvertApp] Writing 312775 bytes to data-prep.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.1.0
# Serving your slides at http://0.0.0.0:8000/data-prep.slides.html
# Use Control-C to stop this server
# WARNING:tornado.access:404 GET /custom.css (172.17.0.1) 2.75ms
# WARNING:tornado.access:404 GET /favicon.ico (172.17.0.1) 1.21ms
# ^C
#
# Interrupted

# %% [markdown]
# # Hands on data wrangling
#
# ## TVB Node 5 Marseille
#
# _Welcome!_

# %% [markdown]
# # Outline
#
# - Softwares, materials, etc
# - Data formats & sources, coordinates & transforms
# - HCP data from structure to simulation
# - Virtual epileptic patient preparation
# - Resources

# %% [markdown]
# All the materials in this talk are available at
#
#     https://github.com/the-virtual-brain/tvb-node5-data
#
# and these slides are available as an executable, interactive IPython/Jupyter notebook.

# %% [markdown]
# The software used in this talk has been conveniently packaged as a Docker container, making it available on Windows, macOS, Linux and most cloud providers, with zero installation effort.
#
# Download the image:
# ```bash
# docker pull maedoc/recon
# ```
# and immediately run commands, e.g. FreeSurfers' pipeline
# ```bash
# docker run --rm -it maedoc/recon recon-all ...
# ```
# or the notebook server
# ```bash
# docker run --rm -it maedoc/recon jupyter notebook
# ```

# %% [markdown]
# ## Keeping TVB up to date
#
# We want to make sure we're working with the latest version.  TVB is open sourced, on GitHub, so it's straightforward to grab the latest version:

# %%
!(cd /opt/tvb-library; git checkout trunk; git pull --rebase)
# Out:
# Switched to branch 'trunk'
# Your branch is up-to-date with 'origin/trunk'.
# Current branch trunk is up to date.

# %% [markdown]
# Or a branch

# %%
!(cd /opt/tvb-library; git checkout sys-stdout)
# Out:
# Branch sys-stdout set up to track remote branch sys-stdout from origin.
# Switched to a new branch 'sys-stdout'

# %%
# %pylab inline

from tvb.simulator.lab import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
conn = connectivity.Connectivity(load_default=True)

figure(figsize=(10,4))
subplot(121), imshow(conn.weights), colorbar()
subplot(122), imshow(conn.tract_lengths), colorbar();

# %% [markdown]
# Just to check, we've also got FreeSurfer, FSL, Mrtrix3, OpenMEEG, MNE available.

# %%
# !which mri_convert
# !which fsl5.0-flirt
# !which mrconvert
# !which om_assemble
# !which mne_watershed_bem
# Out:
# /opt/freesurfer/bin/mri_convert
# /usr/bin/fsl5.0-flirt
# /opt/mrtrix3/bin/mrconvert
# /usr/local/bin/om_assemble
# /opt/MNE-2.7.0-3106-Linux-x86_64/bin/mne_watershed_bem

# %% [markdown]
# # HCP data

# %% [markdown]
# # HCP simulation

# %% [markdown]
# # Epileptic patient data

# %% [markdown]
# # CT electrodes

# %% [markdown]
#   asddf
#
#
# asdf
#
#
# asddf
#
#
# asdf
#
#
# asddf
#
#
# asdf
#
#
# asddf
#
#
# asdf
#
#
# asddf
#
#
# asdf
